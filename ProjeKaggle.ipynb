# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the csv file

data = pd.read_csv("/Users/macbookair/Desktop/KaggleProjeleri/rotten_tomatoes_top_movies.csv")

# See the first five row of the dataset

data.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
# Read Headers

data.columns

# Read each column

data.title 
data["title"] # Another optio to read each column.

# You can see different columns.

data[["title", "year", "synopsis"]]


# Read each row

data.head(4)
# Out:
#                                   title  year  \
# 0                         Black Panther  2018
# 1                     Avengers: Endgame  2019
# 2        Mission: Impossible -- Fallout  2018
# 3                    Mad Max: Fury Road  2015
# 4     Spider-Man: Into the Spider-Verse  2018
# ...                                 ...   ...
# 1605                             Priest  2011
# 1606                     September Dawn  2006
# 1607                   American Outlaws  2001
# 1608                          Jonah Hex  2010
# 1609                      Texas Rangers  2001
#
#                                                synopsis
# 0     After the death of his father, T'Challa return...
# 1     Adrift in space with no food or water, Tony St...
# 2     Ethan Hunt and the IMF team join forces with C...
# 3     Years after the collapse of civilization, the ...
# 4     Bitten by a radioactive spider in the subway, ...
# ...                                                 ...
# ...

# %%
# There are several method to access the indexes
# You can reach the each row
data.iloc[2:4]

# You can reach the specific location

data.iloc[2,4]
# Out:
# 97

# %%
# You can reach both index and specific row 

for index, row in data.iterrows():
    print(index, row)
# Out:
# 0 Unnamed: 0                                                                  0
# title                                                           Black Panther
# year                                                                     2018
# synopsis                    After the death of his father, T'Challa return...
# critic_score                                                               96
# people_score                                                             79.0
# consensus                   Black Panther elevates superhero cinema to thr...
# total_reviews                                                             519
# total_ratings                                                         50,000+
# type                                                       Action & Adventure
# rating                      PG-13 (Sequences of Action Violence|A Brief Ru...
# genre                                              adventure, action, fantasy
# ...

# %%
data.loc[data["title"] == "Black Panther"]["year"]
# Out:
# 0       2018
# 600     2018
# 1200    2018
# Name: year, dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0         year  critic_score  people_score  total_reviews
# count  1610.000000  1610.000000   1610.000000   1609.000000    1610.000000
# mean    804.500000  1991.745963     92.693789     83.405221     143.652174
# std     464.911282    28.054120     11.621759     11.263792     118.137144
# min       0.000000  1919.000000      2.000000     10.000000      39.000000
# 25%     402.250000  1969.000000     92.000000     80.000000      56.000000
# 50%     804.500000  2005.000000     96.000000     87.000000      90.000000
# 75%    1206.750000  2014.000000     98.000000     91.000000     205.750000
# max    1609.000000  2020.000000    100.000000     98.000000     561.000000

# %%
data.sort_values("title", ascending = False)
# Out:
#       Unnamed: 0                title  year  \
# 415          415             Zootopia  2016
# 107          107             Zootopia  2016
# 16            16             Zootopia  2016
# 765          765           Zombieland  2009
# 137          137            Your Name  2016
# ...          ...                  ...   ...
# 636          636     12 Years a Slave  2013
# 329          329         12 Angry Men  1957
# 666          666         12 Angry Men  1957
# 1283        1283  10 Cloverfield Lane  2016
# 1084        1084  10 Cloverfield Lane  2016
#
#                                                synopsis  critic_score  \
# 415   From the largest elephant to the smallest shre...            98
# 107   From the largest elephant to the smallest shre...            98
# 16    From the largest elephant to the smallest shre...            98
# 765   After a virus turns most people into zombies, ...            89
# 137   A teenage boy and girl embark on a quest to me...            98
# ...

# %%
data.sort_values(["critic_score", "people_score"])
# Out:
#       Unnamed: 0                 title  year  \
# 1609        1609         Texas Rangers  2001
# 1468        1468     Playing for Keeps  2012
# 1525        1525  From Justin to Kelly  2003
# 1608        1608             Jonah Hex  2010
# 1524        1524      The Honeymooners  2005
# ...          ...                   ...   ...
# 558          558                Rewind  2019
# 655          655         Seven Samurai  1954
# 666          666          12 Angry Men  1957
# 520          520     Stop Making Sense  1984
# 922          922     Stop Making Sense  1984
#
#                                                synopsis  critic_score  \
# 1609  Texas, 1875. In a land without justice, where ...             2
# 1468  Long past his soccer-playing heyday, George Dr...             4
# 1525  In this musical, college student Justin (Justi...            10
# 1608  Having cheated death, gunslinger and bounty hu...            12
# ...

# %%
# How to delete the columns in dataframe

data = data.drop(columns = ["link"])

# %%
data.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
data.iloc[:,]
# Out:
#       Unnamed: 0                              title  year  \
# 0              0                      Black Panther  2018
# 1              1                  Avengers: Endgame  2019
# 2              2     Mission: Impossible -- Fallout  2018
# 3              3                 Mad Max: Fury Road  2015
# 4              4  Spider-Man: Into the Spider-Verse  2018
# ...          ...                                ...   ...
# 1605        1605                             Priest  2011
# 1606        1606                     September Dawn  2006
# 1607        1607                   American Outlaws  2001
# 1608        1608                          Jonah Hex  2010
# 1609        1609                      Texas Rangers  2001
#
#                                                synopsis  critic_score  \
# 0     After the death of his father, T'Challa return...            96
# 1     Adrift in space with no food or water, Tony St...            94
# ...

# %%
data.iloc[:,1:5]
# Out:
#                                   title  year  \
# 0                         Black Panther  2018
# 1                     Avengers: Endgame  2019
# 2        Mission: Impossible -- Fallout  2018
# 3                    Mad Max: Fury Road  2015
# 4     Spider-Man: Into the Spider-Verse  2018
# ...                                 ...   ...
# 1605                             Priest  2011
# 1606                     September Dawn  2006
# 1607                   American Outlaws  2001
# 1608                          Jonah Hex  2010
# 1609                      Texas Rangers  2001
#
#                                                synopsis  critic_score
# 0     After the death of his father, T'Challa return...            96
# 1     Adrift in space with no food or water, Tony St...            94
# 2     Ethan Hunt and the IMF team join forces with C...            97
# 3     Years after the collapse of civilization, the ...            97
# ...

# %%
cols = list(data.columns.values)

# %%
for index, names in data.iterrows():
    print(index, names.loc[["title","year"]])
# Out:
# 0 title    Black Panther
# year              2018
# Name: 0, dtype: object
# 1 title    Avengers: Endgame
# year                  2019
# Name: 1, dtype: object
# 2 title    Mission: Impossible -- Fallout
# year                               2018
# Name: 2, dtype: object
# 3 title    Mad Max: Fury Road
# year                   2015
# Name: 3, dtype: object
# 4 title    Spider-Man: Into the Spider-Verse
# year                                  2018
# Name: 4, dtype: object
# 5 title    Wonder Woman
# year             2017
# Name: 5, dtype: object
# 6 title    Dunkirk
# year        2017
# Name: 6, dtype: object
# 7 title    Coco
# year     2017
# Name: 7, dtype: object
# 8 title    Thor: Ragnarok
# year               2017
# Name: 8, dtype: object
# 9 title    Logan
# year      2017
# Name: 9, dtype: object
# 10 title    Star Wars: The Last Jedi
# year                         2017
# Name: 10, dtype: object
# 11 title    Star Wars: The Force Awakens
# year                             2015
# ...

# %%
data.loc[1:4]
# Out:
#    Unnamed: 0                              title  year  \
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 1          90.0  Exciting, entertaining, and emotionally impact...
# 2          88.0  Fast, sleek, and fun, Mission: Impossible - Fa...
# 3          86.0  With exhilarating action and a surprising amou...
# 4          93.0  Spider-Man: Into the Spider-Verse matches bold...
#
# ...

# %%
# I would like to see the first 5 row & 4th and 5th column
data.iloc[0:4,4:6]
# Out:
#    critic_score  people_score
# 0            96          79.0
# 1            94          90.0
# 2            97          88.0
# 3            97          86.0

# %%
# if I want to reach the values by using .loc function, remember this function include last number you wrote. 
# You can use it as you want to reach the values by using column names.
data.loc[0:3,["critic_score", "people_score"]]
# Out:
#    critic_score  people_score
# 0            96          79.0
# 1            94          90.0
# 2            97          88.0
# 3            97          86.0

# %%
data.shape
# Out:
# (1610, 25)

# %%
data.shape[0]
# Out:
# 1610

# %%
data.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
data.reset_index(drop = True).head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
data.reset_index(drop = True,inplace = True)
data.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                              title  year  \
# 0           0                      Black Panther  2018
# 1           1                  Avengers: Endgame  2019
# 2           2     Mission: Impossible -- Fallout  2018
# 3           3                 Mad Max: Fury Road  2015
# 4           4  Spider-Man: Into the Spider-Verse  2018
#
#                                             synopsis  critic_score  \
# 0  After the death of his father, T'Challa return...            96
# 1  Adrift in space with no food or water, Tony St...            94
# 2  Ethan Hunt and the IMF team join forces with C...            97
# 3  Years after the collapse of civilization, the ...            97
# 4  Bitten by a radioactive spider in the subway, ...            97
#
#    people_score                                          consensus  \
# 0          79.0  Black Panther elevates superhero cinema to thr...
# 1          90.0  Exciting, entertaining, and emotionally impact...
# ...

# %%
# Let's filter the dataframe

len(data.loc[(data["year"] ==2018) & (data["people_score"] > 90)])
# Out:
# 12

# %%
# The films which Tom cruise has role.
data[data["title"].str.contains("Black")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, year, synopsis, critic_score, people_score, consensus, total_reviews, total_ratings, type, rating, genre, original_language, director, producer, writer, release_date_(theaters), release_date_(streaming), box_office_(gross_usa), runtime, production_co, sound_mix, aspect_ratio, view_the_collection, crew]
# Index: []
#
# [0 rows x 25 columns]

# %%
filt = data["crew"].str.contains("Tom Cruise")
data[filt]
# Out:
#       Unnamed: 0                             title  year  \
# 2              2    Mission: Impossible -- Fallout  2018
# 34            34  Mission: Impossible Rogue Nation  2015
# 607          607    Mission: Impossible -- Fallout  2018
# 1003        1003    Mission: Impossible -- Fallout  2018
# 1252        1252                  Edge of Tomorrow  2014
# 1421        1421                The Color of Money  1986
#
#                                                synopsis  critic_score  \
# 2     Ethan Hunt and the IMF team join forces with C...            97
# 34    With the IMF now disbanded and Ethan Hunt (Tom...            94
# 607   Ethan Hunt and the IMF team join forces with C...            97
# 1003  Ethan Hunt and the IMF team join forces with C...            97
# 1252  When Earth falls under attack from invincible ...            91
# 1421  Former pool hustler "Fast Eddie" Felson (Paul ...            89
#
# ...

# %%
new_data = data.groupby("type").people_score.mean()

# %%
new_data = new_data.to_frame()

# %%
new_data.columns
# Out:
# Index(['people_score'], dtype='object')

# %%
new_data
# Out:
#                            people_score
# type
# Action & Adventure            87.030000
# Animation                     83.490000
# Art House & International     87.610000
# Classics                      90.090000
# Comedy                        85.160000
# Documentary                   83.890000
# Drama                         86.240000
# Horror                        77.580000
# Kids & Family                 82.240000
# Musical & Performing Arts     85.760000
# Mystery & Suspense            86.360000
# Romance                       85.060606
# Science Fiction & Fantasy     85.800000
# Special Interest              84.060000
# Sports & Fitness              78.318841
# Television                    71.070175
# Western                       68.952381

# %%
new_data.iloc[new_data["people_score"].argmax()]
# Out:
# people_score    90.09
# Name: Classics, dtype: float64
